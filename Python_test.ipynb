# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sample-output/Sample Output - Sample Output.csv
# /kaggle/input/sample-input/Sample Input - Sample.csv.csv

# %%
import re
df = pd.read_csv('../input/sample-input/Sample Input - Sample.csv.csv')
df = df[['ItemId', 'ComputerId', 'ItemName', 'Comment']]
df1 = df[['ItemId','ComputerId']].iloc[22:41]
df1['event_timestamp']= df1['ItemId']+' '+df1['ComputerId']
df1 = df1['event_timestamp']
df1 = pd.Series(df1,name='event_timestamp')
df1 = pd.DataFrame(df1)
df = df[0:19]
df = df.rename(columns={'ItemId':'tag_id','ItemName':'tag_name','Comment':'tag_desc','Unit':'tag_unit'})
df[['tag_desc','tag_unit']] = df['tag_desc'].str.split('(', expand=True)
df.tag_unit.str.replace("[),]", "", regex=True)
df = df[['tag_id','tag_name','tag_desc','tag_unit']]
#df1.loc[df1.index.repeat(6)]
#df.loc[df.index.repeat(6)]
df=pd.concat([df,df1])
df['event_timestamp'] = df['event_timestamp'].fillna('06-05-2022 21:58:33')
df = df[0:19]
first_column = df.pop('event_timestamp')
df.insert(0, 'event_timestamp', first_column)
df = df.loc[df.index.repeat(6)]
df
# Out:
#         event_timestamp tag_id        tag_name  \
# 0   06-05-2022 21:58:33  35827  L_R1SDW_SPDREF
# 0   06-05-2022 21:58:33  35827  L_R1SDW_SPDREF
# 0   06-05-2022 21:58:33  35827  L_R1SDW_SPDREF
# 0   06-05-2022 21:58:33  35827  L_R1SDW_SPDREF
# 0   06-05-2022 21:58:33  35827  L_R1SDW_SPDREF
# ..                  ...    ...             ...
# 18  06-05-2022 21:58:33  83540  L_R1_CNT_PASS0
# 18  06-05-2022 21:58:33  83540  L_R1_CNT_PASS0
# 18  06-05-2022 21:58:33  83540  L_R1_CNT_PASS0
# 18  06-05-2022 21:58:33  83540  L_R1_CNT_PASS0
# 18  06-05-2022 21:58:33  83540  L_R1_CNT_PASS0
#
#                              tag_desc tag_unit
# 0   R1 Screw Down WS Speed Reference      mps)
# 0   R1 Screw Down WS Speed Reference      mps)
# 0   R1 Screw Down WS Speed Reference      mps)
# 0   R1 Screw Down WS Speed Reference      mps)
# 0   R1 Screw Down WS Speed Reference      mps)
# ..                                ...      ...
# 18               R1 CONTROL PASS ZERO     None
# ...

# %%
df.to_csv('output_csv1.csv', index=False)
